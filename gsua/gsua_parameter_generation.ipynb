# %% [markdown]
# ## Global Sensitivity and Uncertainty Analysis
#
# The GSUA approach is based on the work of  A. Carmona-Cabrero and R. Muñoz-Carpena, University of Florida. The paper can be found  in JASS:  [(Carmona-Cabrero et al., 2024)](https://doi.org/10.18564/jasss.5174)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from SALib.sample import sobol
from ring_plot_funct import ring_plot

# %%
import json
import pandas as pd
from pathlib import Path

# Folder containing config files
CONFIG_DIR = Path("/blue/carpena/haasehelen/ifwaste/bash-scripts/configuration")

def extract_parameters(d, path=""):
    result = {}
    for key, value in d.items():
        current_path = f"{path}:{key}" if path else key

        if isinstance(value, dict):
            if "value" in value and "layer" in value:
                result[current_path] = {
                    "value": value.get("value", "NAN"),
                    "distribution":  value.get("distribution", "NAN"),
                    "bounds":  value.get("bounds", "NAN"),
                    "layer": value["layer"],
                    "dtype": value.get("dtype", "NAN"),
                    "length": value.get("length", "NAN"),
                    "options":value.get("options", []),
                    "decimals": value.get("decimals", "NAN")
                }
            elif "distribution" in value:
                result[current_path] = {
                    "value":  value.get("value", "NAN"),
                    "distribution": value["distribution"],
                    "bounds":  value.get("bounds", "NAN"),
                    "layer": value.get("layer", value["distribution"]),
                    "dtype": value.get("dtype", "NAN"),
                    "length": value.get("length", "NAN"),
                    "options":value.get("options", []),
                    "decimals": value.get("decimals", "NAN")
                }
            else:
                nested_result = extract_parameters(value, current_path)
                result.update(nested_result)
    return result

# Collect all JSON config files
all_json_files = list(CONFIG_DIR.glob("*.json"))
# Collect DataFrames
df_list = []
for json_file in all_json_files:
    with open(json_file) as f:
        config = json.load(f)
    flat_params = extract_parameters(config)
    df = pd.DataFrame.from_dict(flat_params, orient="index")
    df.index.name = "name"
    df.reset_index(inplace=True)
    df.replace("", "NAN", inplace=True)
    df_list.append(df)

# Combine all into one big DataFrame
df = pd.concat(df_list, ignore_index=True)


constants = df[df["value"] != "NAN"]

parameter = df[df["value"] == "NAN"]

mask = (parameter["distribution"] == "triang") | (parameter["distribution"] == "unif")
simple_distributions = parameter[mask ]

other_distributions = parameter[~(mask)]
other_distributions
# Out:
#                                                   name value distribution  \
# 10   Premium_retailer:Sales:high_stock_discount_int...   NAN        sales
# 13            Premium_retailer:Sales:seasonal_discount   NAN        sales
# 18   Premium_retailer:Sales:clearance_interval_1_di...   NAN        sales
# 24   Convenience_store:Sales:high_stock_discount_in...   NAN        sales
# 27           Convenience_store:Sales:seasonal_discount   NAN        sales
# 32   Convenience_store:Sales:clearance_interval_1_d...   NAN        sales
# 37                       Neighborhood:nh_store_amounts   NAN       vector
# 94                     Household:hh_shopping_frequency   NAN     subgroup
# 96                       Household:hh_pay_day_interval   NAN     subgroup
# 107                      Adult:adult_preference_vector   NAN       vector
# 123                      Child:child_preference_vector   NAN       vector
# 144  Discount_retailer:Sales:high_stock_discount_in...   NAN        sales
# 147          Discount_retailer:Sales:seasonal_discount   NAN        sales
# 152  Discount_retailer:Sales:clearance_interval_1_d...   NAN        sales
#
#                                       bounds         layer  dtype length  \
# 10                                       NAN  neighborhood    NAN    NAN
# 13                                       NAN  neighborhood    NAN    NAN
# 18                                       NAN  neighborhood    NAN    NAN
# 24                                       NAN  neighborhood    NAN    NAN
# 27                                       NAN  neighborhood    NAN    NAN
# 32                                       NAN  neighborhood    NAN    NAN
# 37                                    [0, 1]  neighborhood    int      3
# 94   {'1-2': 0.08, '3-6': 0.12, '7-10': 0.8}     household    int    NAN
# 96    {'14': 0.628, '30': 0.103, '7': 0.269}     household    int    NAN
# 107                                   [0, 1]     household  float      7
# 123                                   [0, 1]     household  float      7
# 144                                      NAN  neighborhood    NAN    NAN
# 147                                      NAN  neighborhood    NAN    NAN
# 152                                      NAN  neighborhood    NAN    NAN
#
#                                                options decimals
# 10                                        [DISCOUNT10]      NAN
# 13                                        [DISCOUNT10]      NAN
# 18                                        [DISCOUNT10]      NAN
# 24   [DISCOUNT20, DISCOUNT30, DISCOUNT40, DISCOUNT5...      NAN
# 27   [DISCOUNT10, DISCOUNT20, DISCOUNT30, DISCOUNT4...      NAN
# 32                [DISCOUNT10, DISCOUNT20, DISCOUNT30]      NAN
# 37                                                  []      NAN
# 94                                                  []      NAN
# 96                                                  []      NAN
# 107                                                 []        2
# 123                                                 []        2
# 144                                 [DISCOUNT50, BOGO]      NAN
# 147  [BOGO, DISCOUNT20, DISCOUNT30, DISCOUNT40, DIS...      NAN
# 152  [BOGO, DISCOUNT20, DISCOUNT30, DISCOUNT40, DIS...      NAN

# %%
constants
# Out:
#                                                   name  value distribution  \
# 0                                      Simulation:runs      1          NAN
# 1                                Simulation:total_days    100          NAN
# 2                                      Simulation:name  debug          NAN
# 3                             Simulation:output_folder   data          NAN
# 4                    Simulation:write_to_file_interval      1          NAN
# ..                                                 ...    ...          ...
# 149  Discount_retailer:Sales:clearance_interval_1_e...      3          NAN
# 150  Discount_retailer:Sales:clearance_interval_2_e...   None          NAN
# 151  Discount_retailer:Sales:clearance_interval_3_e...   None          NAN
# 153  Discount_retailer:Sales:clearance_interval_2_d...   None          NAN
# 154  Discount_retailer:Sales:clearance_interval_3_d...   None          NAN
#
#     bounds       layer dtype length options decimals
# 0      NAN  simulation   NAN    NAN      []      NAN
# 1      NAN  simulation   NAN    NAN      []      NAN
# 2      NAN  simulation   NAN    NAN      []      NAN
# 3      NAN  simulation   NAN    NAN      []      NAN
# 4      NAN  simulation   NAN    NAN      []      NAN
# ..     ...         ...   ...    ...     ...      ...
# 149    NAN  simulation   NAN    NAN      []      NAN
# 150    NAN  simulation   NAN    NAN      []      NAN
# 151    NAN  simulation   NAN    NAN      []      NAN
# 153    NAN  simulation   NAN    NAN      []      NAN
# 154    NAN  simulation   NAN    NAN      []      NAN
#
# [70 rows x 9 columns]

# %%
other_distributions
# Out:
#                                                   name value distribution  \
# 10   Premium_retailer:Sales:high_stock_discount_int...   NAN        sales
# 13            Premium_retailer:Sales:seasonal_discount   NAN        sales
# 18   Premium_retailer:Sales:clearance_interval_1_di...   NAN        sales
# 24   Convenience_store:Sales:high_stock_discount_in...   NAN        sales
# 27           Convenience_store:Sales:seasonal_discount   NAN        sales
# 32   Convenience_store:Sales:clearance_interval_1_d...   NAN        sales
# 37                       Neighborhood:nh_store_amounts   NAN       vector
# 94                     Household:hh_shopping_frequency   NAN     subgroup
# 96                       Household:hh_pay_day_interval   NAN     subgroup
# 107                      Adult:adult_preference_vector   NAN       vector
# 123                      Child:child_preference_vector   NAN       vector
# 144  Discount_retailer:Sales:high_stock_discount_in...   NAN        sales
# 147          Discount_retailer:Sales:seasonal_discount   NAN        sales
# 152  Discount_retailer:Sales:clearance_interval_1_d...   NAN        sales
#
#                                       bounds         layer  dtype length  \
# 10                                       NAN  neighborhood    NAN    NAN
# 13                                       NAN  neighborhood    NAN    NAN
# 18                                       NAN  neighborhood    NAN    NAN
# 24                                       NAN  neighborhood    NAN    NAN
# 27                                       NAN  neighborhood    NAN    NAN
# 32                                       NAN  neighborhood    NAN    NAN
# 37                                    [0, 1]  neighborhood    int      3
# 94   {'1-2': 0.08, '3-6': 0.12, '7-10': 0.8}     household    int    NAN
# 96    {'14': 0.628, '30': 0.103, '7': 0.269}     household    int    NAN
# 107                                   [0, 1]     household  float      7
# 123                                   [0, 1]     household  float      7
# 144                                      NAN  neighborhood    NAN    NAN
# 147                                      NAN  neighborhood    NAN    NAN
# 152                                      NAN  neighborhood    NAN    NAN
#
#                                                options decimals
# 10                                        [DISCOUNT10]      NAN
# 13                                        [DISCOUNT10]      NAN
# 18                                        [DISCOUNT10]      NAN
# 24   [DISCOUNT20, DISCOUNT30, DISCOUNT40, DISCOUNT5...      NAN
# 27   [DISCOUNT10, DISCOUNT20, DISCOUNT30, DISCOUNT4...      NAN
# 32                [DISCOUNT10, DISCOUNT20, DISCOUNT30]      NAN
# 37                                                  []      NAN
# 94                                                  []      NAN
# 96                                                  []      NAN
# 107                                                 []        2
# 123                                                 []        2
# 144                                 [DISCOUNT50, BOGO]      NAN
# 147  [BOGO, DISCOUNT20, DISCOUNT30, DISCOUNT40, DIS...      NAN
# 152  [BOGO, DISCOUNT20, DISCOUNT30, DISCOUNT40, DIS...      NAN

# %%
#convert other distributions to sobol-sampleable values
for _,row in other_distributions.iterrows(): 
    if row["distribution"] == "subgroup": 
        new_row = pd.DataFrame({"name":row["name"], "distribution":"unif", "bounds":[[0,1]], "dtype":"float",
                            "decimals":2, "layer": row["layer"], "value":"NAN", "options":"NAN"})
        simple_distributions = pd.concat([simple_distributions, new_row], ignore_index=True)
        
    if row["distribution"] == "vector": 
        for i in range(row["length"]): 
            new_row = pd.DataFrame({"name":row["name"]+"_"+str(i), "distribution":"unif", "bounds":[[0,1]], "dtype":row["dtype"],
                            "decimals":2, "layer": row["layer"], "value":"NAN", "options":"NAN"})
            simple_distributions = pd.concat([simple_distributions, new_row], ignore_index=True)
            
    if row["distribution"] == "sales": 
        new_row = pd.DataFrame({"name":row["name"], "distribution":"unif", "bounds":[[0,1]], "dtype":"float",
                            "decimals":2, "layer": row["layer"], "value":"NAN", "options":"NAN"})
        #sales werden dann von vorne nach hinten ausgewählt - nicht noch randomisiert - zack 
        simple_distributions = pd.concat([simple_distributions, new_row], ignore_index=True)

# %%
simple_distributions
# Out:
#                                                  name value distribution  \
# 0        Premium_retailer:Sales:high_stock_interval_1   NAN         unif
# 1          Premium_retailer:Sales:seasonal_likelihood   NAN         unif
# 2       Convenience_store:Sales:high_stock_interval_1   NAN         unif
# 3         Convenience_store:Sales:seasonal_likelihood   NAN         unif
# 4              Neighborhood:Grid:travel_time_per_cell   NAN       triang
# ..                                                ...   ...          ...
# 94                    Child:child_preference_vector_5   NAN         unif
# 95                    Child:child_preference_vector_6   NAN         unif
# 96  Discount_retailer:Sales:high_stock_discount_in...   NAN         unif
# 97          Discount_retailer:Sales:seasonal_discount   NAN         unif
# 98  Discount_retailer:Sales:clearance_interval_1_d...   NAN         unif
#
#          bounds         layer  dtype length options decimals
# 0    [1.3, 1.5]  neighborhood  float    NAN      []        2
# 1     [0, 0.05]  neighborhood  float    NAN      []        2
# 2      [1, 1.5]  neighborhood  float    NAN      []        2
# 3     [0, 0.25]  neighborhood  float    NAN      []        2
# 4   [3, 7, 0.5]  neighborhood  float    NAN      []        1
# ..          ...           ...    ...    ...     ...      ...
# 94       [0, 1]     household  float    NaN     NAN        2
# 95       [0, 1]     household  float    NaN     NAN        2
# 96       [0, 1]  neighborhood  float    NaN     NAN        2
# 97       [0, 1]  neighborhood  float    NaN     NAN        2
# 98       [0, 1]  neighborhood  float    NaN     NAN        2
#
# [99 rows x 9 columns]

# %%
#sample other distributions by hand: subgroup
#import random

#def get_value_for_subgroup(bounds):
## Step 1: Extract ranges and probabilities
#    ranges = []
#    probs = []
#    for key, prob in bounds.items():
#        start, end = map(int, key.split('-'))
#        ranges.append((start, end))
#        probs.append(prob)
#    chosen_range = random.choices(ranges, weights=probs, k=1)[0]
#    sampled_value = random.randint(chosen_range[0], chosen_range[1])

#for row in other_distributions.rows: 
#    if row["distribution"] == "subgroup":
#        row["value"] = get_value_for_subgroup(row["bounds"])
#    elif row["distribution"] == "vector": 
#        if row["name"].contains["store_amounts"]:

# %%
'''import random

def get_value_for_subgroup(bounds):
    ranges = []
    probs = []

    for key, prob in bounds.items():
        if '-' in key:
            start, end = map(int, key.split('-'))
        else:
            start = end = int(key)  # Single value case
        ranges.append((start, end))
        probs.append(prob)

    # Choose a range/value based on probability
    chosen_range = random.choices(ranges, weights=probs, k=1)[0]
    sampled_value = random.randint(chosen_range[0], chosen_range[1])
    
    return sampled_value
print(get_value_for_subgroup({'14': 0.628, '30': 0.103, '7': 0.269}))'''
# Out:
# "import random\n\ndef get_value_for_subgroup(bounds):\n    ranges = []\n    probs = []\n\n    for key, prob in bounds.items():\n        if '-' in key:\n            start, end = map(int, key.split('-'))\n        else:\n            start = end = int(key)  # Single value case\n        ranges.append((start, end))\n        probs.append(prob)\n\n    # Choose a range/value based on probability\n    chosen_range = random.choices(ranges, weights=probs, k=1)[0]\n    sampled_value = random.randint(chosen_range[0], chosen_range[1])\n    \n    return sampled_value\nprint(get_value_for_subgroup({'14': 0.628, '30': 0.103, '7': 0.269}))"

# %%
l = 4  # Sampling intensity
N = 10

# %%
problems = {}

for layer in simple_distributions["layer"].unique():
        names = simple_distributions["name"].to_list()
        distributions = simple_distributions["distribution"].to_list()
        bounds = simple_distributions["bounds"].to_list()
        problem = {'num_vars': len(names),
        'names': names,
        'bounds': bounds,
        'dists':distributions
        }
        param_values = pd.DataFrame(sobol.sample(problem, l, calc_second_order=False), columns=names)  # calc_second_order=True for second-order interactions. 
        print("GSA sample matrix size: {}".format(param_values.shape))
# Out:
# GSA sample matrix size: (404, 99)
# GSA sample matrix size: (404, 99)

# %%
param_values
# Out:
#      Premium_retailer:Sales:high_stock_interval_1  \
# 0                                        1.453692
# 1                                        1.311823
# 2                                        1.453692
# 3                                        1.453692
# 4                                        1.453692
# ..                                            ...
# 399                                      1.402689
# 400                                      1.402689
# 401                                      1.402689
# 402                                      1.402689
# 403                                      1.366524
#
#      Premium_retailer:Sales:seasonal_likelihood  \
# 0                                      0.013536
# 1                                      0.013536
# 2                                      0.015112
# 3                                      0.013536
# 4                                      0.013536
# ..                                          ...
# 399                                    0.043948
# 400                                    0.043948
# 401                                    0.043948
# 402                                    0.043948
# 403                                    0.045440
#
#      Convenience_store:Sales:high_stock_interval_1  \
# 0                                         1.011261
# 1                                         1.011261
# 2                                         1.011261
# 3                                         1.023733
# 4                                         1.011261
# ..                                             ...
# 399                                       1.340484
# 400                                       1.340484
# 401                                       1.340484
# 402                                       1.340484
# 403                                       1.460681
#
#      Convenience_store:Sales:seasonal_likelihood  \
# 0                                       0.059033
# 1                                       0.059033
# 2                                       0.059033
# 3                                       0.059033
# 4                                       0.027259
# ..                                           ...
# 399                                     0.207384
# 400                                     0.207384
# 401                                     0.207384
# 402                                     0.207384
# 403                                     0.089609
#
#      Neighborhood:Grid:travel_time_per_cell  \
# 0                                  4.392566
# 1                                  4.392566
# 2                                  4.392566
# 3                                  4.392566
# 4                                  4.392566
# ..                                      ...
# 399                                4.473596
# 400                                4.473596
# 401                                4.473596
# 402                                4.473596
# 403                                5.270895
#
#      Neighborhood:BasketCurator:increment_likelihood  \
# 0                                           0.943491
# 1                                           0.943491
# 2                                           0.943491
# 3                                           0.943491
# 4                                           0.943491
# ..                                               ...
# 399                                         0.553472
# 400                                         0.553472
# 401                                         0.553472
# 402                                         0.553472
# 403                                         0.300633
#
#      Neighborhood:BasketCurator:max_items_quickshop  \
# 0                                          5.256637
# 1                                          5.256637
# 2                                          5.256637
# 3                                          5.256637
# 4                                          5.256637
# ..                                              ...
# 399                                        4.806584
# 400                                        4.806584
# 401                                        4.806584
# 402                                        4.806584
# 403                                        3.924174
#
#      Neighborhood:Food:FGMeat:expiration  \
# 0                               5.553667
# 1                               5.553667
# 2                               5.553667
# 3                               5.553667
# 4                               5.553667
# ..                                   ...
# 399                             4.380087
# 400                             4.380087
# 401                             4.380087
# 402                             4.380087
# 403                             9.766416
#
#      Neighborhood:Food:FGMeat:impulse_buy_likelihood  \
# 0                                           0.396931
# 1                                           0.396931
# 2                                           0.396931
# 3                                           0.396931
# 4                                           0.396931
# ..                                               ...
# 399                                         0.566567
# 400                                         0.566567
# 401                                         0.566567
# 402                                         0.566567
# 403                                         0.885807
#
#      Neighborhood:Food:FGDairy:expiration  ...  \
# 0                                9.557176  ...
# 1                                9.557176  ...
# 2                                9.557176  ...
# 3                                9.557176  ...
# 4                                9.557176  ...
# ..                                    ...  ...
# 399                             20.668627  ...
# 400                             20.668627  ...
# 401                             20.668627  ...
# 402                             20.668627  ...
# 403                             18.054236  ...
#
#      Child:child_preference_vector_0  Child:child_preference_vector_1  \
# 0                           0.053811                         0.695255
# 1                           0.053811                         0.695255
# 2                           0.053811                         0.695255
# 3                           0.053811                         0.695255
# 4                           0.053811                         0.695255
# ..                               ...                              ...
# 399                         0.300447                         0.101941
# 400                         0.300447                         0.101941
# 401                         0.300447                         0.101941
# 402                         0.300447                         0.101941
# 403                         0.194907                         0.453257
#
#      Child:child_preference_vector_2  Child:child_preference_vector_3  \
# 0                           0.291455                         0.600928
# 1                           0.291455                         0.600928
# 2                           0.291455                         0.600928
# 3                           0.291455                         0.600928
# 4                           0.291455                         0.600928
# ..                               ...                              ...
# 399                         0.222342                         0.022912
# 400                         0.222342                         0.022912
# 401                         0.222342                         0.022912
# 402                         0.222342                         0.022912
# 403                         0.621209                         0.057015
#
#      Child:child_preference_vector_4  Child:child_preference_vector_5  \
# 0                           0.023446                         0.110840
# 1                           0.023446                         0.110840
# 2                           0.023446                         0.110840
# 3                           0.023446                         0.110840
# 4                           0.023446                         0.110840
# ..                               ...                              ...
# 399                         0.681660                         0.363306
# 400                         0.681660                         0.363306
# 401                         0.681660                         0.363306
# 402                         0.681660                         0.363306
# 403                         0.112304                         0.951271
#
#      Child:child_preference_vector_6  \
# 0                           0.761810
# 1                           0.761810
# 2                           0.761810
# 3                           0.761810
# 4                           0.761810
# ..                               ...
# 399                         0.169553
# 400                         0.335326
# 401                         0.335326
# 402                         0.335326
# 403                         0.169553
#
#      Discount_retailer:Sales:high_stock_discount_interval_1  \
# 0                                             0.554469
# 1                                             0.554469
# 2                                             0.554469
# 3                                             0.554469
# 4                                             0.554469
# ..                                                 ...
# 399                                           0.778634
# 400                                           0.008597
# 401                                           0.778634
# 402                                           0.778634
# 403                                           0.008597
#
#      Discount_retailer:Sales:seasonal_discount  \
# 0                                     0.366080
# 1                                     0.366080
# 2                                     0.366080
# 3                                     0.366080
# 4                                     0.366080
# ..                                         ...
# 399                                   0.975433
# 400                                   0.975433
# 401                                   0.805258
# 402                                   0.975433
# 403                                   0.805258
#
#      Discount_retailer:Sales:clearance_interval_1_discount
# 0                                             0.500096
# 1                                             0.500096
# 2                                             0.500096
# 3                                             0.500096
# 4                                             0.500096
# ..                                                 ...
# 399                                           0.224844
# 400                                           0.224844
# 401                                           0.224844
# 402                                           0.542821
# 403                                           0.542821
#
# [404 rows x 99 columns]

# %%
#convert to correct dtype with correct rounding

for param_name in param_values.columns: 
    row = simple_distributions[simple_distributions["name"] == param_name]
    if row["dtype"].values[0] == "int":
        param_values[param_name] = param_values[param_name].round()
    elif row["dtype"].values[0] == "float": 
        param_values[param_name] = param_values[param_name].astype("float").round(int(row["decimals"].values[0]))

# %%
param_values
# Out:
#      Premium_retailer:Sales:high_stock_interval_1  \
# 0                                            1.45
# 1                                            1.31
# 2                                            1.45
# 3                                            1.45
# 4                                            1.45
# ..                                            ...
# 399                                          1.40
# 400                                          1.40
# 401                                          1.40
# 402                                          1.40
# 403                                          1.37
#
#      Premium_retailer:Sales:seasonal_likelihood  \
# 0                                          0.01
# 1                                          0.01
# 2                                          0.02
# 3                                          0.01
# 4                                          0.01
# ..                                          ...
# 399                                        0.04
# 400                                        0.04
# 401                                        0.04
# 402                                        0.04
# 403                                        0.05
#
#      Convenience_store:Sales:high_stock_interval_1  \
# 0                                             1.01
# 1                                             1.01
# 2                                             1.01
# 3                                             1.02
# 4                                             1.01
# ..                                             ...
# 399                                           1.34
# 400                                           1.34
# 401                                           1.34
# 402                                           1.34
# 403                                           1.46
#
#      Convenience_store:Sales:seasonal_likelihood  \
# 0                                           0.06
# 1                                           0.06
# 2                                           0.06
# 3                                           0.06
# 4                                           0.03
# ..                                           ...
# 399                                         0.21
# 400                                         0.21
# 401                                         0.21
# 402                                         0.21
# 403                                         0.09
#
#      Neighborhood:Grid:travel_time_per_cell  \
# 0                                       4.4
# 1                                       4.4
# 2                                       4.4
# 3                                       4.4
# 4                                       4.4
# ..                                      ...
# 399                                     4.5
# 400                                     4.5
# 401                                     4.5
# 402                                     4.5
# 403                                     5.3
#
#      Neighborhood:BasketCurator:increment_likelihood  \
# 0                                               0.94
# 1                                               0.94
# 2                                               0.94
# 3                                               0.94
# 4                                               0.94
# ..                                               ...
# 399                                             0.55
# 400                                             0.55
# 401                                             0.55
# 402                                             0.55
# 403                                             0.30
#
#      Neighborhood:BasketCurator:max_items_quickshop  \
# 0                                               5.0
# 1                                               5.0
# 2                                               5.0
# 3                                               5.0
# 4                                               5.0
# ..                                              ...
# 399                                             5.0
# 400                                             5.0
# 401                                             5.0
# 402                                             5.0
# 403                                             4.0
#
#      Neighborhood:Food:FGMeat:expiration  \
# 0                                    6.0
# 1                                    6.0
# 2                                    6.0
# 3                                    6.0
# 4                                    6.0
# ..                                   ...
# 399                                  4.0
# 400                                  4.0
# 401                                  4.0
# 402                                  4.0
# 403                                 10.0
#
#      Neighborhood:Food:FGMeat:impulse_buy_likelihood  \
# 0                                               0.40
# 1                                               0.40
# 2                                               0.40
# 3                                               0.40
# 4                                               0.40
# ..                                               ...
# 399                                             0.57
# 400                                             0.57
# 401                                             0.57
# 402                                             0.57
# 403                                             0.89
#
#      Neighborhood:Food:FGDairy:expiration  ...  \
# 0                                    10.0  ...
# 1                                    10.0  ...
# 2                                    10.0  ...
# 3                                    10.0  ...
# 4                                    10.0  ...
# ..                                    ...  ...
# 399                                  21.0  ...
# 400                                  21.0  ...
# 401                                  21.0  ...
# 402                                  21.0  ...
# 403                                  18.0  ...
#
#      Child:child_preference_vector_0  Child:child_preference_vector_1  \
# 0                               0.05                             0.70
# 1                               0.05                             0.70
# 2                               0.05                             0.70
# 3                               0.05                             0.70
# 4                               0.05                             0.70
# ..                               ...                              ...
# 399                             0.30                             0.10
# 400                             0.30                             0.10
# 401                             0.30                             0.10
# 402                             0.30                             0.10
# 403                             0.19                             0.45
#
#      Child:child_preference_vector_2  Child:child_preference_vector_3  \
# 0                               0.29                             0.60
# 1                               0.29                             0.60
# 2                               0.29                             0.60
# 3                               0.29                             0.60
# 4                               0.29                             0.60
# ..                               ...                              ...
# 399                             0.22                             0.02
# 400                             0.22                             0.02
# 401                             0.22                             0.02
# 402                             0.22                             0.02
# 403                             0.62                             0.06
#
#      Child:child_preference_vector_4  Child:child_preference_vector_5  \
# 0                               0.02                             0.11
# 1                               0.02                             0.11
# 2                               0.02                             0.11
# 3                               0.02                             0.11
# 4                               0.02                             0.11
# ..                               ...                              ...
# 399                             0.68                             0.36
# 400                             0.68                             0.36
# 401                             0.68                             0.36
# 402                             0.68                             0.36
# 403                             0.11                             0.95
#
#      Child:child_preference_vector_6  \
# 0                               0.76
# 1                               0.76
# 2                               0.76
# 3                               0.76
# 4                               0.76
# ..                               ...
# 399                             0.17
# 400                             0.34
# 401                             0.34
# 402                             0.34
# 403                             0.17
#
#      Discount_retailer:Sales:high_stock_discount_interval_1  \
# 0                                                 0.55
# 1                                                 0.55
# 2                                                 0.55
# 3                                                 0.55
# 4                                                 0.55
# ..                                                 ...
# 399                                               0.78
# 400                                               0.01
# 401                                               0.78
# 402                                               0.78
# 403                                               0.01
#
#      Discount_retailer:Sales:seasonal_discount  \
# 0                                         0.37
# 1                                         0.37
# 2                                         0.37
# 3                                         0.37
# 4                                         0.37
# ..                                         ...
# 399                                       0.98
# 400                                       0.98
# 401                                       0.81
# 402                                       0.98
# 403                                       0.81
#
#      Discount_retailer:Sales:clearance_interval_1_discount
# 0                                                 0.50
# 1                                                 0.50
# 2                                                 0.50
# 3                                                 0.50
# 4                                                 0.50
# ..                                                 ...
# 399                                               0.22
# 400                                               0.22
# 401                                               0.22
# 402                                               0.54
# 403                                               0.54
#
# [404 rows x 99 columns]

# %%
#for HPC added "sens_class" line
param_values = pd.concat([pd.DataFrame(['sens_class'] * param_values.shape[0]), param_values], axis=1)
param_values.head()
        
#filter out unperformable sets (no stores in simulation)
print(len(param_values))
param_values = param_values[~((param_values['Neighborhood:nh_store_amounts_0'] + param_values['Neighborhood:nh_store_amounts_1'] + param_values['Neighborhood:nh_store_amounts_2']) == 0)]
print(len(param_values))
# Out:
# 404
# 305

# %%
sample_matrix_realizations = pd.DataFrame(np.repeat(param_values.to_numpy(), repeats=N, axis=0))
print("GSA sample matrix size: {}".format(sample_matrix_realizations.shape))
#write the sample matrix to csv to configure the model

sample_matrix_realizations.to_csv('{}_ifwaste_sample.txt'.format(layer), header=False, index=False, sep='\t')
df["name"].to_csv('{}_ifwaste_sample_header.txt'.format(layer), index=False, header=False)
# Out:
# GSA sample matrix size: (4040, 100)

# %% [markdown]
# Generating the GSA sample matrix

# %%
param_values = pd.DataFrame(sobol.sample(problem, l, calc_second_order=False), columns=names)  # calc_second_order=True for second-order interactions. 
print("GSA sample matrix size: {}".format(param_values.shape))

#for HPC added "sens_class" line
sample_matrix = pd.concat([pd.DataFrame(['sens_class'] * param_values.shape[0]), param_values], axis=1)
sample_matrix.head()

sample_matrix_realizations = pd.DataFrame(np.repeat(sample_matrix.to_numpy(), repeats=N, axis=0))
print("GSA sample matrix size: {}".format(sample_matrix_realizations.shape))
#write the sample matrix to csv to configure the model

#sample_matrix_realizations.to_csv('{}_layer.txt'.format(layer), header=False, index=False, sep='\t')
# Out:
# GSA sample matrix size: (404, 99)
# GSA sample matrix size: (4040, 100)
